# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import pickle as pkl
import cv2
import imutils
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50V2, DenseNet121, VGG19, EfficientNetB7, InceptionV3, MobileNetV3Large
from keras.applications.resnet_v2 import preprocess_input as resnet_v2_preprocess_input
from keras.applications.densenet import preprocess_input as densenet_preprocess_input
from keras.applications.vgg19 import preprocess_input as vgg19_preprocess_input
from keras.applications.inception_v3 import preprocess_input as inception_v3_preprocess_input
from keras.applications.mobilenet_v3 import preprocess_input as mobilenet_v3_preprocess_input
from keras.applications.efficientnet import preprocess_input as efficientnet_preprocess_input
from keras.models import Model, Sequential
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.layers import LSTM, Conv2D, GlobalAveragePooling2D, GlobalMaxPooling2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation, Conv2DTranspose, Reshape, Input, ReLU, LeakyReLU, TimeDistributed
from keras.regularizers import L2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.metrics import AUC, Precision, Recall, Accuracy
from kerastuner import HyperModel
from kerastuner.tuners import Hyperband
import visualkeras
from keras.utils import plot_model
import re
# Out:
# C:\Users\farha\AppData\Local\Temp\ipykernel_14092\2761402677.py:27: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import HyperModel

# %%
""" Dataset directories """
dataset_dir = "final_dataset"
# dataset_dir = "Segmented_dataset"
# dataset_dir = "filtered_dataset"
# dataset_dir = "archive/Data"

# %%
""" Get the first image from the healthy directory """
first_image_file = os.listdir(f"{dataset_dir}/No Dementia")[0]
img = plt.imread(f"{dataset_dir}/No Dementia/{first_image_file}")

img_height, img_width, _ = img.shape

img_size = 224
# img_size = min(img_height, img_width)

print(f"Image size: {img_height}x{img_width} -> {img_size}x{img_size}")
# Out:
# Image size: 248x496 -> 224x224

# %% [markdown]
# #### General preprocessing and augmentation

# %%
""" Display raw images from different classes """
plt.figure(figsize=(8, 8))

for i, subdir in enumerate(os.listdir(dataset_dir)):
    subdir_path = os.path.join(dataset_dir, subdir)
    img_files = os.listdir(subdir_path)[:4]

    for j, img_file in enumerate(img_files):
        img_path = os.path.join(subdir_path, img_file)
        img = plt.imread(img_path)

        plt.subplot(4, 4, i * 4 + j + 1)
        plt.imshow(img)
        plt.title(subdir)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Custom preprocessing on Images

# %%
def apply_clahe(img):
    # Convert image to grayscale
    grayscale_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization) for contrast enhancement
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    equalized_img = clahe.apply(grayscale_img)

    return equalized_img


def enhance_sharpness(img):
    # Apply Laplacian sharpening to enhance details
    laplacian = cv2.Laplacian(img, cv2.CV_8U, ksize=3)

    # Add the original image with the sharpened details
    sharpened_img = cv2.addWeighted(img, 1.5, laplacian, -0.5, 0)

    return sharpened_img


def crop_image(img, add_pixels_value=1):
    # Apply Gaussian blur to reduce noise
    gray_blur = cv2.GaussianBlur(img, (5, 5), 0)

    # Thresholding to create a binary image
    _, thresh = cv2.threshold(gray_blur, 45, 255, cv2.THRESH_BINARY)

    # Morphological operations (erosion and dilation) to remove noise
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours
    contours = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(contours)

    # If no contours found, return original image
    if len(contours) == 0:
        return img

    # Get the largest contour
    largest_contour = max(contours, key=cv2.contourArea)

    # Get the bounding box of the largest contour
    x, y, w, h = cv2.boundingRect(largest_contour)

    # Add extra pixels to the bounding box if specified
    x -= add_pixels_value
    y -= add_pixels_value
    w += add_pixels_value * 2
    h += add_pixels_value * 2

    # Ensure the bounding box coordinates are within image bounds
    x = max(x, 0)
    y = max(y, 0)
    w = min(w, img.shape[1])
    h = min(h, img.shape[0])

    # Crop the image using the bounding box
    cropped_img = img[y : y + h, x : x + w].copy()

    return cropped_img


def resize_image(img, size):
    # Resize the image to the specified size
    resized_img = cv2.resize(img, (size, size), interpolation=cv2.INTER_AREA)

    return resized_img

# %%
"""
    Change run cell to True if you need the preprocessed images. Then keep toggle as False to only get the final preprocessed images.
"""

prep_dir_1 = "dataset_preprocessed_1_clahe"
prep_dir_2 = "dataset_preprocessed_2_sharp"
prep_dir_3 = "dataset_preprocessed_3_crop"
prep_dir_4 = "dataset_preprocessed_4_final"

# Flag for this cell
run_cell = False

if run_cell:
    # Local save intermediate outputs toggle
    toggle = False

    # Create directories if they don't exist
    for prep_dir in [prep_dir_1, prep_dir_2, prep_dir_3, prep_dir_4]:
        if not os.path.exists(prep_dir):
            os.makedirs(prep_dir)

    for subdir in os.listdir(dataset_dir):
        subdir_path = os.path.join(dataset_dir, subdir)

        # Create subdirectories in each preprocessing directory
        for prep_dir in [prep_dir_1, prep_dir_2, prep_dir_3, prep_dir_4]:
            new_subdir_path = os.path.join(prep_dir, subdir)
            if not os.path.exists(new_subdir_path):
                os.makedirs(new_subdir_path)

        for filename in os.listdir(subdir_path):
            img_path = os.path.join(subdir_path, filename)
            img = plt.imread(img_path)

            # Apply CLAHE and save the result in prep_dir_1
            clahe_img = apply_clahe(img)
            new_filename = os.path.join(prep_dir_1, subdir, filename)
            if toggle:
                plt.imsave(new_filename, clahe_img, cmap="gray")

            # Enhance sharpness and save the result in prep_dir_2
            sharp_img = enhance_sharpness(clahe_img)
            new_filename = os.path.join(prep_dir_2, subdir, filename)
            if toggle:
                plt.imsave(new_filename, sharp_img, cmap="gray")

            # Crop image and save the result in prep_dir_3
            cropp_image = crop_image(sharp_img)
            new_filename = os.path.join(prep_dir_3, subdir, filename)
            if toggle:
                plt.imsave(new_filename, cropp_image, cmap="gray")

            # Resize image to 224x224 and save the result in prep_dir_4
            preprocessed_img = resize_image(cropp_image, img_size)
            new_filename = os.path.join(prep_dir_4, subdir, filename)
            plt.imsave(new_filename, preprocessed_img, cmap="gray")

prep_dir = prep_dir_4

# %%
# def custom_preprocess(img):
#     # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization) for contrast enhancement
#     clahe_img = apply_clahe(img)

#     # Enhance sharpness
#     sharp_img = enhance_sharpness(clahe_img)

#     # Crop image
#     cropped_img = crop_image(sharp_img)

#     # Resize image to 224x224
#     preprocessed_img = resize_image(cropped_img, img_size)

#     return preprocessed_img

# %% [markdown]
# #### Filter the Data

# %%
# # Given images are in naming syntax of "OAS1_0001_MR1_mpr-1_100.jpg". I want to only keep the images that end between _120.jpg and _140.jpg
# pattern = re.compile(r".*_(12[0-9]|13[0-9]|140).jpg")

# for sub_dir in os.listdir(prep_dir):
#     for img_file in os.listdir(f"{prep_dir}/{sub_dir}"):
#         if not pattern.match(img_file):
#             os.remove(f"{prep_dir}/{sub_dir}/{img_file}")

# %%
""" Display raw images from different classes """
plt.figure(figsize=(8, 8))

for i, subdir in enumerate(os.listdir(prep_dir)):
    subdir_path = os.path.join(prep_dir, subdir)
    img_files = os.listdir(subdir_path)[:4]

    for j, img_file in enumerate(img_files):
        img_path = os.path.join(subdir_path, img_file)
        img = plt.imread(img_path)

        plt.subplot(4, 4, i * 4 + j + 1)
        plt.imshow(img)
        plt.title(subdir)

plt.tight_layout()
plt.show()

# %%
# Set batch size
batch_size = 64

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=10,
    brightness_range=[0.9, 1.1],
    validation_split=0.2,
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(prep_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode="categorical", subset="training", shuffle=True, seed=42)
val_generator = val_datagen.flow_from_directory(prep_dir, target_size=(img_size, img_size), batch_size=batch_size, class_mode="categorical", subset="validation", shuffle=False, seed=42)
# Out:
# Found 5309 images belonging to 2 classes.
# Found 1327 images belonging to 2 classes.

# %%
# Display some of the training augmented images
plt.figure(figsize=(8, 8))

for i in range(16):
    img = train_generator[0][0][i]
    plt.subplot(4, 4, i + 1)
    plt.imshow(img)
    plt.axis("off")
    
plt.tight_layout()
plt.show()

# %%
# # Display some of the validation augmented images
# plt.figure(figsize=(8, 8))

# for i in range(16):
#     img = val_generator[0][0][i]
#     plt.subplot(4, 4, i + 1)
#     plt.imshow(img)
#     plt.axis("off")
    
# plt.tight_layout()
# plt.show()

# %%
""" Get class labels """
class_labels = list(train_generator.class_indices.keys())

# %%
""" Number of classes"""
num_classes = len(class_labels)

# %% [markdown]
# ## 1. Custom CNN model

# %% [markdown]
# #### Keras-Tuned CNN model

# %%
# # Model configuration
# epochs_number = 200

# # Set learning rate annealer
# learning_rate_reduction = ReduceLROnPlateau(monitor="val_loss", patience=6, verbose=1, mode='min', factor=0.75, min_lr=0.00001)

# # Checkpoint
# checkpoint_filepath = "models/custom_CNN_model.h5"
# model_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor="val_accuracy", mode="max", save_best_only=True)

# %%
# class CNNHyperModel(HyperModel):
#     def __init__(self, img_size, num_classes):
#         self.img_size = img_size
#         self.num_classes = num_classes

#     def build(self, hp):
#         model = Sequential()

#         # First Conv Block
#         model.add(
#             Conv2D(
#                 filters=hp.Choice("input_filters", values=[16, 32, 64]),
#                 kernel_size=hp.Choice("input_kernel_size", values=[3, 5, 7]),
#                 padding="same",
#                 activation="relu",
#                 input_shape=(self.img_size, self.img_size, 3),
#                 kernel_regularizer=L2(hp.Float("input_l2", min_value=0.000001, max_value=0.1, sampling="LOG")),
#             )
#         )
#         model.add(BatchNormalization())
#         model.add(MaxPooling2D(pool_size=(hp.Choice("input_pool_size", values=[2, 3]), hp.Choice("input_pool_size", values=[2, 3]))))
#         model.add(Dropout(hp.Float("input_dropout", min_value=0.0, max_value=0.5, step=0.05)))

#         # Additional Conv Blocks
#         num_blocks = hp.Choice("num_conv_blocks", values=[1, 2, 3, 4, 5])
#         for i in range(1, num_blocks + 1):
#             model.add(
#                 Conv2D(
#                     filters=hp.Choice(f"filters_{num_blocks}_{i}", values=[32, 64, 128, 256]),
#                     kernel_size=hp.Choice(f"kernel_size_{i}", values=[3, 5, 7]),
#                     padding="same",
#                     activation="relu",
#                     kernel_regularizer=L2(hp.Float(f"l2_{num_blocks}_{i}", min_value=0.000001, max_value=0.1, sampling="LOG")),
#                 )
#             )
#             model.add(BatchNormalization())
#             model.add(MaxPooling2D(pool_size=(hp.Choice(f"pool_size_{num_blocks}_{i}", values=[2, 3]), hp.Choice(f"pool_size_{i}", values=[2, 3]))))
#             model.add(Dropout(hp.Float(f"dropout_{num_blocks}_{i}", min_value=0.0, max_value=0.5, step=0.05)))

#         # Flatten and Dense Layers
#         model.add(Flatten())
#         model.add(
#             Dense(
#                 units=hp.Choice("units_dense", values=[256, 512, 1024]),
#                 activation="relu",
#                 kernel_regularizer=L2(hp.Float("l2_dense", min_value=0.000001, max_value=0.1, sampling="LOG")),
#             )
#         )
#         model.add(BatchNormalization())
#         model.add(Dropout(hp.Float("dropout_dense", min_value=0.0, max_value=0.5, step=0.05)))
#         model.add(Dense(self.num_classes, activation="sigmoid"))

#         # Optimizer Selection
#         optimizer_choice = hp.Choice("optimizer", ["adam", "rmsprop", "sgd"])
#         if optimizer_choice == "adam":
#             optimizer = Adam(
#                 learning_rate=hp.Float("learning_rate_adam", min_value=0.0001, max_value=0.01, sampling="LOG"),
#                 beta_1=hp.Float("beta_1_adam", min_value=0.5, max_value=0.9, step=0.05),
#                 beta_2=hp.Float("beta_2_adam", min_value=0.995, max_value=0.999, step=0.001),
#             )
#         elif optimizer_choice == "rmsprop":
#             optimizer = RMSprop(
#                 learning_rate=hp.Float("learning_rate_rms", min_value=0.0001, max_value=0.01, sampling="LOG"),
#                 rho=hp.Float("rho_rms", min_value=0.8, max_value=0.99, step=0.05),
#             )
#         elif optimizer_choice == "sgd":
#             optimizer = SGD(
#                 learning_rate=hp.Float("learning_rate_sgd", min_value=0.0001, max_value=0.01, sampling="LOG"),
#                 momentum=hp.Float("momentum_sgd", min_value=0.0, max_value=0.9, step=0.1),
#                 nesterov=hp.Boolean("nesterov_sgd"),
#             )

#         model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
        
#         return model


# hypermodel = CNNHyperModel(img_size, num_classes)

# tuner = Hyperband(hypermodel, objective="val_accuracy", directory="hyperband_hpo", project_name="cnn")

# # tuner.search_space_summary()

# %%
# tuner.search(
#     train_generator,
#     validation_data=val_generator,
#     epochs=epochs_number,
#     verbose=1,
#     callbacks=[learning_rate_reduction, model_checkpoint],
# )

# %%
# # Get the optimal hyperparameters
# best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
# best_hps.values

# %%
# custom_CNN_model = tuner.hypermodel.build(best_hps)
# custom_CNN_model.summary()

# %%
# # Compile model again with a learning rate of 0.0001
# optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# # Set learning rate annealer
# learning_rate_reduction = ReduceLROnPlateau(monitor="val_accuracy", patience=6, verbose=1, mode='max', factor=0.5, min_lr=0.00001)

# custom_CNN_model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])

# %%
# # visualkeras.layered_view(model).show()
# # visualkeras.layered_view(model, to_file='output.png')
# # visualkeras.layered_view(model, to_file='output.png').show()

# visualkeras.layered_view(custom_CNN_model)

# %%
# from keras.utils import plot_model

# plot_model(custom_CNN_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# # Train the model
# custom_CNN_history = custom_CNN_model.fit(
#     train_generator, 
#     epochs=epochs_number, 
#     validation_data=val_generator, 
#     callbacks=[model_checkpoint, learning_rate_reduction],
#     # callbacks=[learning_rate_reduction, early_stopping, model_checkpoint],
# )

# %%
# # Save the trained model
# custom_CNN_model.save("models/final_custom_CNN_model.h5")

# # Save history
# with open("models/final_custom_CNN_history.pkl", "wb") as f:
#     pkl.dump(custom_CNN_history.history, f)

# %%
# fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# # Plot training and validation accuracy
# axs[0].plot(custom_CNN_history.history["accuracy"], label="Training accuracy")
# axs[0].plot(custom_CNN_history.history["val_accuracy"], label="Validation accuracy")
# axs[0].set_title("Training and validation accuracy - Custom CNN")
# axs[0].set_xlabel("Epoch")
# axs[0].set_ylabel("Accuracy")
# axs[0].legend()

# # Plot training and validation loss
# axs[1].plot(custom_CNN_history.history["loss"], label="Training loss")
# axs[1].plot(custom_CNN_history.history["val_loss"], label="Validation loss")
# axs[1].set_title("Training and validation loss - Custom CNN")
# axs[1].set_xlabel("Epoch")
# axs[1].set_ylabel("Loss")
# axs[1].legend()

# plt.tight_layout()
# plt.show()

# %% [markdown]
# #### Base CNN Model

# %%
# Model configuration
epochs_number = 200

# Set optimizer
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# optimizer = SGD(learning_rate=0.001, momentum=0.9, nesterov=True)

# Set early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=5, verbose=1, mode='min', min_delta=0.01, restore_best_weights=True)

# Set learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor="val_loss", patience=3, verbose=1, mode='min', factor=0.75, min_lr=0.00001)

# Checkpoint
checkpoint_filepath = "models/custom_CNN_model_v2.h5"
model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)

# %%
# Custom CNN architecture
custom_CNN_model = Sequential(
    [
        Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=(img_size, img_size, 3), kernel_regularizer=L2(0.01)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.25),
        
        Conv2D(64, (3, 3), padding="same", activation="relu", kernel_regularizer=L2(0.01)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.25),
        
        Conv2D(128, (3, 3), padding="same", activation="relu", kernel_regularizer=L2(0.01)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.4),
        
        Conv2D(256, (3, 3), padding="same", activation="relu", kernel_regularizer=L2(0.01)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.4),
        
        Flatten(),
        
        Dense(512, activation="relu", kernel_regularizer=L2(0.01)),
        BatchNormalization(),
        Dropout(0.5),
        Dense(num_classes, activation="sigmoid"),
    ]
)

# Compile the model
custom_CNN_model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])

# Show model summary
custom_CNN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  batch_normalization (BatchN  (None, 224, 224, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  dropout (Dropout)           (None, 112, 112, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 56, 56, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 28, 28, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 14, 14, 256)       0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 512)               25690624
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 26,084,034
# Trainable params: 26,082,050
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
visualkeras.layered_view(custom_CNN_model)
# Out:
# <PIL.Image.Image image mode=RGBA size=1289x1195>

# %%
plot_model(custom_CNN_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Train the model
custom_CNN_history = custom_CNN_model.fit(
    train_generator, 
    epochs=epochs_number, 
    validation_data=val_generator, 
    callbacks=[model_checkpoint, learning_rate_reduction],
    # callbacks=[learning_rate_reduction, early_stopping, model_checkpoint],
)
# Out:
# Epoch 1/200
# 83/83 [==============================] - 44s 489ms/step - loss: 8.3886 - accuracy: 0.8361 - val_loss: 6.4341 - val_accuracy: 0.4943 - lr: 0.0010
# Epoch 2/200
# 83/83 [==============================] - 39s 469ms/step - loss: 2.8612 - accuracy: 0.8778 - val_loss: 4.3315 - val_accuracy: 0.5057 - lr: 0.0010
# Epoch 3/200
# 83/83 [==============================] - 39s 465ms/step - loss: 1.9109 - accuracy: 0.8904 - val_loss: 9.1503 - val_accuracy: 0.4943 - lr: 0.0010
# Epoch 4/200
# 83/83 [==============================] - 39s 469ms/step - loss: 1.6000 - accuracy: 0.8981 - val_loss: 2.6108 - val_accuracy: 0.5057 - lr: 0.0010
# Epoch 5/200
# 83/83 [==============================] - 39s 465ms/step - loss: 1.7863 - accuracy: 0.8998 - val_loss: 2.3328 - val_accuracy: 0.4876 - lr: 0.0010
# Epoch 6/200
# 83/83 [==============================] - 39s 465ms/step - loss: 1.7010 - accuracy: 0.9073 - val_loss: 3.3408 - val_accuracy: 0.5057 - lr: 0.0010
# Epoch 7/200
# 83/83 [==============================] - 39s 467ms/step - loss: 1.6472 - accuracy: 0.9056 - val_loss: 2.8813 - val_accuracy: 0.4815 - lr: 0.0010
# Epoch 8/200
# 83/83 [==============================] - 39s 473ms/step - loss: 1.5570 - accuracy: 0.9113 - val_loss: 1.7769 - val_accuracy: 0.7242 - lr: 0.0010
# Epoch 9/200
# 83/83 [==============================] - 39s 466ms/step - loss: 1.4427 - accuracy: 0.9126 - val_loss: 2.2887 - val_accuracy: 0.5185 - lr: 0.0010
# Epoch 10/200
# 83/83 [==============================] - 39s 467ms/step - loss: 1.5679 - accuracy: 0.9100 - val_loss: 2.2541 - val_accuracy: 0.6549 - lr: 0.0010
# Epoch 11/200
# 83/83 [==============================] - ETA: 0s - loss: 1.4778 - accuracy: 0.9098
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# 83/83 [==============================] - 39s 470ms/step - loss: 1.4778 - accuracy: 0.9098 - val_loss: 1.8957 - val_accuracy: 0.7702 - lr: 0.0010
# Epoch 12/200
# 83/83 [==============================] - 39s 470ms/step - loss: 1.3269 - accuracy: 0.9145 - val_loss: 1.6866 - val_accuracy: 0.7732 - lr: 7.5000e-04
# Epoch 13/200
# 83/83 [==============================] - 39s 466ms/step - loss: 1.0649 - accuracy: 0.9224 - val_loss: 2.1689 - val_accuracy: 0.6172 - lr: 7.5000e-04
# Epoch 14/200
# 83/83 [==============================] - 39s 467ms/step - loss: 1.1456 - accuracy: 0.9194 - val_loss: 2.2534 - val_accuracy: 0.5998 - lr: 7.5000e-04
# Epoch 15/200
# 83/83 [==============================] - 39s 466ms/step - loss: 1.0579 - accuracy: 0.9299 - val_loss: 1.5484 - val_accuracy: 0.7491 - lr: 7.5000e-04
# Epoch 16/200
# 83/83 [==============================] - 39s 465ms/step - loss: 1.1297 - accuracy: 0.9215 - val_loss: 1.8939 - val_accuracy: 0.6360 - lr: 7.5000e-04
# Epoch 17/200
# 83/83 [==============================] - 39s 471ms/step - loss: 1.1423 - accuracy: 0.9184 - val_loss: 1.7561 - val_accuracy: 0.7136 - lr: 7.5000e-04
# Epoch 18/200
# 83/83 [==============================] - ETA: 0s - loss: 1.1384 - accuracy: 0.9264
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# 83/83 [==============================] - 39s 466ms/step - loss: 1.1384 - accuracy: 0.9264 - val_loss: 2.3919 - val_accuracy: 0.6029 - lr: 7.5000e-04
# Epoch 19/200
# 83/83 [==============================] - 39s 466ms/step - loss: 1.0353 - accuracy: 0.9320 - val_loss: 1.8552 - val_accuracy: 0.6345 - lr: 5.6250e-04
# Epoch 20/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.8566 - accuracy: 0.9305 - val_loss: 1.9473 - val_accuracy: 0.6631 - lr: 5.6250e-04
# Epoch 21/200
# 83/83 [==============================] - ETA: 0s - loss: 0.8704 - accuracy: 0.9324
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# 83/83 [==============================] - 39s 469ms/step - loss: 0.8704 - accuracy: 0.9324 - val_loss: 2.5236 - val_accuracy: 0.5750 - lr: 5.6250e-04
# Epoch 22/200
# 83/83 [==============================] - 39s 472ms/step - loss: 0.7840 - accuracy: 0.9399 - val_loss: 1.4831 - val_accuracy: 0.6390 - lr: 4.2187e-04
# Epoch 23/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.6765 - accuracy: 0.9465 - val_loss: 1.5541 - val_accuracy: 0.6639 - lr: 4.2187e-04
# Epoch 24/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.6419 - accuracy: 0.9490 - val_loss: 1.6662 - val_accuracy: 0.7008 - lr: 4.2187e-04
# Epoch 25/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.6284 - accuracy: 0.9441 - val_loss: 1.3552 - val_accuracy: 0.7106 - lr: 4.2187e-04
# Epoch 26/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.6307 - accuracy: 0.9465 - val_loss: 1.3226 - val_accuracy: 0.6910 - lr: 4.2187e-04
# Epoch 27/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.6974 - accuracy: 0.9377 - val_loss: 2.7676 - val_accuracy: 0.5885 - lr: 4.2187e-04
# Epoch 28/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.6480 - accuracy: 0.9484 - val_loss: 1.3327 - val_accuracy: 0.7393 - lr: 4.2187e-04
# Epoch 29/200
# 83/83 [==============================] - ETA: 0s - loss: 0.6101 - accuracy: 0.9503
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# 83/83 [==============================] - 39s 465ms/step - loss: 0.6101 - accuracy: 0.9503 - val_loss: 1.7135 - val_accuracy: 0.7076 - lr: 4.2187e-04
# Epoch 30/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.6550 - accuracy: 0.9424 - val_loss: 1.5723 - val_accuracy: 0.7423 - lr: 3.1641e-04
# Epoch 31/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.5713 - accuracy: 0.9535 - val_loss: 1.3550 - val_accuracy: 0.7332 - lr: 3.1641e-04
# Epoch 32/200
# 83/83 [==============================] - ETA: 0s - loss: 0.5561 - accuracy: 0.9542
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# 83/83 [==============================] - 39s 466ms/step - loss: 0.5561 - accuracy: 0.9542 - val_loss: 1.5352 - val_accuracy: 0.7069 - lr: 3.1641e-04
# Epoch 33/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.5093 - accuracy: 0.9610 - val_loss: 2.2905 - val_accuracy: 0.5682 - lr: 2.3730e-04
# Epoch 34/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.4606 - accuracy: 0.9648 - val_loss: 2.1967 - val_accuracy: 0.6315 - lr: 2.3730e-04
# Epoch 35/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.4606 - accuracy: 0.9633 - val_loss: 1.2038 - val_accuracy: 0.7460 - lr: 2.3730e-04
# Epoch 36/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.4283 - accuracy: 0.9719 - val_loss: 1.4112 - val_accuracy: 0.6993 - lr: 2.3730e-04
# Epoch 37/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.4495 - accuracy: 0.9668 - val_loss: 1.4693 - val_accuracy: 0.7573 - lr: 2.3730e-04
# Epoch 38/200
# 83/83 [==============================] - ETA: 0s - loss: 0.4513 - accuracy: 0.9657
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
# 83/83 [==============================] - 39s 468ms/step - loss: 0.4513 - accuracy: 0.9657 - val_loss: 1.3869 - val_accuracy: 0.7016 - lr: 2.3730e-04
# Epoch 39/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.4231 - accuracy: 0.9682 - val_loss: 1.2610 - val_accuracy: 0.7581 - lr: 1.7798e-04
# Epoch 40/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.3570 - accuracy: 0.9778 - val_loss: 1.7512 - val_accuracy: 0.6390 - lr: 1.7798e-04
# Epoch 41/200
# 83/83 [==============================] - ETA: 0s - loss: 0.3479 - accuracy: 0.9731
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
# 83/83 [==============================] - 39s 468ms/step - loss: 0.3479 - accuracy: 0.9731 - val_loss: 1.9478 - val_accuracy: 0.5923 - lr: 1.7798e-04
# Epoch 42/200
# 83/83 [==============================] - 39s 463ms/step - loss: 0.3279 - accuracy: 0.9815 - val_loss: 2.0997 - val_accuracy: 0.6021 - lr: 1.3348e-04
# Epoch 43/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.3070 - accuracy: 0.9793 - val_loss: 1.5552 - val_accuracy: 0.6217 - lr: 1.3348e-04
# Epoch 44/200
# 83/83 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.9832
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
# 83/83 [==============================] - 39s 467ms/step - loss: 0.2889 - accuracy: 0.9832 - val_loss: 1.3251 - val_accuracy: 0.7393 - lr: 1.3348e-04
# Epoch 45/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.2635 - accuracy: 0.9876 - val_loss: 1.5380 - val_accuracy: 0.6541 - lr: 1.0011e-04
# Epoch 46/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.2701 - accuracy: 0.9810 - val_loss: 1.3299 - val_accuracy: 0.7506 - lr: 1.0011e-04
# Epoch 47/200
# 83/83 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.9812
# Epoch 47: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
# 83/83 [==============================] - 39s 470ms/step - loss: 0.2641 - accuracy: 0.9812 - val_loss: 1.2986 - val_accuracy: 0.7182 - lr: 1.0011e-04
# Epoch 48/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.2470 - accuracy: 0.9862 - val_loss: 1.2078 - val_accuracy: 0.7506 - lr: 7.5085e-05
# Epoch 49/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.2353 - accuracy: 0.9868 - val_loss: 1.2920 - val_accuracy: 0.7355 - lr: 7.5085e-05
# Epoch 50/200
# 83/83 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9859
# Epoch 50: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
# 83/83 [==============================] - 39s 470ms/step - loss: 0.2399 - accuracy: 0.9859 - val_loss: 1.2503 - val_accuracy: 0.7234 - lr: 7.5085e-05
# Epoch 51/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.2172 - accuracy: 0.9898 - val_loss: 1.3119 - val_accuracy: 0.7167 - lr: 5.6314e-05
# Epoch 52/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.2119 - accuracy: 0.9887 - val_loss: 1.3594 - val_accuracy: 0.7378 - lr: 5.6314e-05
# Epoch 53/200
# 83/83 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 0.9870
# Epoch 53: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# 83/83 [==============================] - 39s 466ms/step - loss: 0.2093 - accuracy: 0.9870 - val_loss: 1.4781 - val_accuracy: 0.7317 - lr: 5.6314e-05
# Epoch 54/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.2059 - accuracy: 0.9868 - val_loss: 1.3542 - val_accuracy: 0.7272 - lr: 4.2235e-05
# Epoch 55/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1898 - accuracy: 0.9915 - val_loss: 1.3249 - val_accuracy: 0.7589 - lr: 4.2235e-05
# Epoch 56/200
# 83/83 [==============================] - ETA: 0s - loss: 0.1838 - accuracy: 0.9917
# Epoch 56: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1838 - accuracy: 0.9917 - val_loss: 1.3418 - val_accuracy: 0.7551 - lr: 4.2235e-05
# Epoch 57/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.1812 - accuracy: 0.9908 - val_loss: 1.4284 - val_accuracy: 0.7543 - lr: 3.1676e-05
# Epoch 58/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1745 - accuracy: 0.9902 - val_loss: 1.3753 - val_accuracy: 0.7445 - lr: 3.1676e-05
# Epoch 59/200
# 83/83 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9911
# Epoch 59: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1737 - accuracy: 0.9911 - val_loss: 1.3372 - val_accuracy: 0.7543 - lr: 3.1676e-05
# Epoch 60/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.1676 - accuracy: 0.9925 - val_loss: 1.3317 - val_accuracy: 0.7347 - lr: 2.3757e-05
# Epoch 61/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1573 - accuracy: 0.9953 - val_loss: 1.3270 - val_accuracy: 0.7581 - lr: 2.3757e-05
# Epoch 62/200
# 83/83 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9947
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.781794799171621e-05.
# 83/83 [==============================] - 39s 468ms/step - loss: 0.1544 - accuracy: 0.9947 - val_loss: 1.3544 - val_accuracy: 0.7536 - lr: 2.3757e-05
# Epoch 63/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.1523 - accuracy: 0.9947 - val_loss: 1.4204 - val_accuracy: 0.7671 - lr: 1.7818e-05
# Epoch 64/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1507 - accuracy: 0.9951 - val_loss: 1.4934 - val_accuracy: 0.7114 - lr: 1.7818e-05
# Epoch 65/200
# 83/83 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9957
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.3363460311666131e-05.
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1457 - accuracy: 0.9957 - val_loss: 1.4472 - val_accuracy: 0.7257 - lr: 1.7818e-05
# Epoch 66/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1451 - accuracy: 0.9943 - val_loss: 1.4472 - val_accuracy: 0.7325 - lr: 1.3363e-05
# Epoch 67/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.1440 - accuracy: 0.9951 - val_loss: 1.5078 - val_accuracy: 0.7219 - lr: 1.3363e-05
# Epoch 68/200
# 83/83 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9947
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.0022595233749598e-05.
# 83/83 [==============================] - 39s 469ms/step - loss: 0.1425 - accuracy: 0.9947 - val_loss: 1.5150 - val_accuracy: 0.7287 - lr: 1.3363e-05
# Epoch 69/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1383 - accuracy: 0.9955 - val_loss: 1.5260 - val_accuracy: 0.7242 - lr: 1.0023e-05
# Epoch 70/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1381 - accuracy: 0.9951 - val_loss: 1.4793 - val_accuracy: 0.7506 - lr: 1.0023e-05
# Epoch 71/200
# 83/83 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 0.9974
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1e-05.
# 83/83 [==============================] - 39s 468ms/step - loss: 0.1322 - accuracy: 0.9974 - val_loss: 1.4882 - val_accuracy: 0.7430 - lr: 1.0023e-05
# Epoch 72/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.1359 - accuracy: 0.9947 - val_loss: 1.4764 - val_accuracy: 0.7415 - lr: 1.0000e-05
# Epoch 73/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.1355 - accuracy: 0.9943 - val_loss: 1.5932 - val_accuracy: 0.7106 - lr: 1.0000e-05
# Epoch 74/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.1345 - accuracy: 0.9945 - val_loss: 1.5432 - val_accuracy: 0.7151 - lr: 1.0000e-05
# Epoch 75/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1331 - accuracy: 0.9957 - val_loss: 1.5481 - val_accuracy: 0.7189 - lr: 1.0000e-05
# Epoch 76/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1337 - accuracy: 0.9953 - val_loss: 1.4883 - val_accuracy: 0.7317 - lr: 1.0000e-05
# Epoch 77/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1278 - accuracy: 0.9970 - val_loss: 1.5821 - val_accuracy: 0.7099 - lr: 1.0000e-05
# Epoch 78/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.1291 - accuracy: 0.9959 - val_loss: 1.5460 - val_accuracy: 0.7234 - lr: 1.0000e-05
# Epoch 79/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1253 - accuracy: 0.9960 - val_loss: 1.6916 - val_accuracy: 0.7023 - lr: 1.0000e-05
# Epoch 80/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.1278 - accuracy: 0.9959 - val_loss: 1.5994 - val_accuracy: 0.7197 - lr: 1.0000e-05
# Epoch 81/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1252 - accuracy: 0.9960 - val_loss: 1.5383 - val_accuracy: 0.7332 - lr: 1.0000e-05
# Epoch 82/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.1261 - accuracy: 0.9960 - val_loss: 1.6402 - val_accuracy: 0.7069 - lr: 1.0000e-05
# Epoch 83/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.1231 - accuracy: 0.9960 - val_loss: 1.5903 - val_accuracy: 0.7265 - lr: 1.0000e-05
# Epoch 84/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.1217 - accuracy: 0.9976 - val_loss: 1.6404 - val_accuracy: 0.7144 - lr: 1.0000e-05
# Epoch 85/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.1223 - accuracy: 0.9970 - val_loss: 1.6671 - val_accuracy: 0.7272 - lr: 1.0000e-05
# Epoch 86/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.1214 - accuracy: 0.9960 - val_loss: 1.5132 - val_accuracy: 0.7310 - lr: 1.0000e-05
# Epoch 87/200
# 83/83 [==============================] - 40s 476ms/step - loss: 0.1197 - accuracy: 0.9949 - val_loss: 1.5355 - val_accuracy: 0.7438 - lr: 1.0000e-05
# Epoch 88/200
# 83/83 [==============================] - 39s 474ms/step - loss: 0.1198 - accuracy: 0.9964 - val_loss: 1.5732 - val_accuracy: 0.7174 - lr: 1.0000e-05
# Epoch 89/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.1160 - accuracy: 0.9968 - val_loss: 1.6187 - val_accuracy: 0.7287 - lr: 1.0000e-05
# Epoch 90/200
# 83/83 [==============================] - 40s 476ms/step - loss: 0.1153 - accuracy: 0.9977 - val_loss: 1.6348 - val_accuracy: 0.7272 - lr: 1.0000e-05
# Epoch 91/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1181 - accuracy: 0.9960 - val_loss: 1.6011 - val_accuracy: 0.7295 - lr: 1.0000e-05
# Epoch 92/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1155 - accuracy: 0.9953 - val_loss: 1.7978 - val_accuracy: 0.6978 - lr: 1.0000e-05
# Epoch 93/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.1152 - accuracy: 0.9968 - val_loss: 1.6916 - val_accuracy: 0.7159 - lr: 1.0000e-05
# Epoch 94/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.1137 - accuracy: 0.9960 - val_loss: 1.6302 - val_accuracy: 0.7084 - lr: 1.0000e-05
# Epoch 95/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.1138 - accuracy: 0.9949 - val_loss: 1.6436 - val_accuracy: 0.7656 - lr: 1.0000e-05
# Epoch 96/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1149 - accuracy: 0.9959 - val_loss: 1.7097 - val_accuracy: 0.7182 - lr: 1.0000e-05
# Epoch 97/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1127 - accuracy: 0.9964 - val_loss: 1.6422 - val_accuracy: 0.7182 - lr: 1.0000e-05
# Epoch 98/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.1103 - accuracy: 0.9968 - val_loss: 1.5913 - val_accuracy: 0.7257 - lr: 1.0000e-05
# Epoch 99/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.1094 - accuracy: 0.9964 - val_loss: 1.5689 - val_accuracy: 0.7400 - lr: 1.0000e-05
# Epoch 100/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.1080 - accuracy: 0.9970 - val_loss: 1.8268 - val_accuracy: 0.6940 - lr: 1.0000e-05
# Epoch 101/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.1078 - accuracy: 0.9968 - val_loss: 1.6353 - val_accuracy: 0.7272 - lr: 1.0000e-05
# Epoch 102/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.1073 - accuracy: 0.9970 - val_loss: 1.9041 - val_accuracy: 0.6978 - lr: 1.0000e-05
# Epoch 103/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.1076 - accuracy: 0.9962 - val_loss: 1.9562 - val_accuracy: 0.6865 - lr: 1.0000e-05
# Epoch 104/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.1079 - accuracy: 0.9964 - val_loss: 1.7513 - val_accuracy: 0.7076 - lr: 1.0000e-05
# Epoch 105/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.1088 - accuracy: 0.9953 - val_loss: 1.8304 - val_accuracy: 0.7031 - lr: 1.0000e-05
# Epoch 106/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.1055 - accuracy: 0.9970 - val_loss: 1.7998 - val_accuracy: 0.7038 - lr: 1.0000e-05
# Epoch 107/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1039 - accuracy: 0.9976 - val_loss: 1.6555 - val_accuracy: 0.7242 - lr: 1.0000e-05
# Epoch 108/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.1057 - accuracy: 0.9968 - val_loss: 1.7342 - val_accuracy: 0.7287 - lr: 1.0000e-05
# Epoch 109/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.1017 - accuracy: 0.9970 - val_loss: 1.7231 - val_accuracy: 0.7227 - lr: 1.0000e-05
# Epoch 110/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.1047 - accuracy: 0.9964 - val_loss: 1.6982 - val_accuracy: 0.7227 - lr: 1.0000e-05
# Epoch 111/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.1047 - accuracy: 0.9968 - val_loss: 1.7061 - val_accuracy: 0.7362 - lr: 1.0000e-05
# Epoch 112/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.1032 - accuracy: 0.9968 - val_loss: 1.6723 - val_accuracy: 0.7332 - lr: 1.0000e-05
# Epoch 113/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1016 - accuracy: 0.9966 - val_loss: 1.7240 - val_accuracy: 0.7121 - lr: 1.0000e-05
# Epoch 114/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.1026 - accuracy: 0.9968 - val_loss: 1.6460 - val_accuracy: 0.7114 - lr: 1.0000e-05
# Epoch 115/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.0997 - accuracy: 0.9966 - val_loss: 1.6094 - val_accuracy: 0.7325 - lr: 1.0000e-05
# Epoch 116/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.0980 - accuracy: 0.9976 - val_loss: 1.6539 - val_accuracy: 0.7362 - lr: 1.0000e-05
# Epoch 117/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.1015 - accuracy: 0.9960 - val_loss: 1.7999 - val_accuracy: 0.7031 - lr: 1.0000e-05
# Epoch 118/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.1018 - accuracy: 0.9957 - val_loss: 1.6226 - val_accuracy: 0.7476 - lr: 1.0000e-05
# Epoch 119/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0986 - accuracy: 0.9966 - val_loss: 1.8283 - val_accuracy: 0.6963 - lr: 1.0000e-05
# Epoch 120/200
# 83/83 [==============================] - 39s 463ms/step - loss: 0.1035 - accuracy: 0.9951 - val_loss: 1.7077 - val_accuracy: 0.7317 - lr: 1.0000e-05
# Epoch 121/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0959 - accuracy: 0.9983 - val_loss: 1.8418 - val_accuracy: 0.7167 - lr: 1.0000e-05
# Epoch 122/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0982 - accuracy: 0.9974 - val_loss: 1.8155 - val_accuracy: 0.7091 - lr: 1.0000e-05
# Epoch 123/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0958 - accuracy: 0.9981 - val_loss: 1.7944 - val_accuracy: 0.7129 - lr: 1.0000e-05
# Epoch 124/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0961 - accuracy: 0.9968 - val_loss: 1.9570 - val_accuracy: 0.7008 - lr: 1.0000e-05
# Epoch 125/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0966 - accuracy: 0.9966 - val_loss: 1.7300 - val_accuracy: 0.7076 - lr: 1.0000e-05
# Epoch 126/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0950 - accuracy: 0.9968 - val_loss: 1.7689 - val_accuracy: 0.7167 - lr: 1.0000e-05
# Epoch 127/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0947 - accuracy: 0.9968 - val_loss: 1.7916 - val_accuracy: 0.7099 - lr: 1.0000e-05
# Epoch 128/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.0961 - accuracy: 0.9964 - val_loss: 1.6725 - val_accuracy: 0.7362 - lr: 1.0000e-05
# Epoch 129/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0947 - accuracy: 0.9974 - val_loss: 1.5683 - val_accuracy: 0.7445 - lr: 1.0000e-05
# Epoch 130/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0924 - accuracy: 0.9974 - val_loss: 1.7070 - val_accuracy: 0.7212 - lr: 1.0000e-05
# Epoch 131/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.0950 - accuracy: 0.9970 - val_loss: 1.7791 - val_accuracy: 0.7174 - lr: 1.0000e-05
# Epoch 132/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0934 - accuracy: 0.9959 - val_loss: 1.6234 - val_accuracy: 0.7393 - lr: 1.0000e-05
# Epoch 133/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0927 - accuracy: 0.9968 - val_loss: 1.6953 - val_accuracy: 0.7219 - lr: 1.0000e-05
# Epoch 134/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.0946 - accuracy: 0.9960 - val_loss: 1.6731 - val_accuracy: 0.7317 - lr: 1.0000e-05
# Epoch 135/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.0903 - accuracy: 0.9981 - val_loss: 1.7408 - val_accuracy: 0.7106 - lr: 1.0000e-05
# Epoch 136/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0897 - accuracy: 0.9977 - val_loss: 1.7414 - val_accuracy: 0.7325 - lr: 1.0000e-05
# Epoch 137/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.0906 - accuracy: 0.9970 - val_loss: 1.7784 - val_accuracy: 0.7197 - lr: 1.0000e-05
# Epoch 138/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0922 - accuracy: 0.9968 - val_loss: 1.6172 - val_accuracy: 0.7551 - lr: 1.0000e-05
# Epoch 139/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0933 - accuracy: 0.9962 - val_loss: 1.7351 - val_accuracy: 0.7099 - lr: 1.0000e-05
# Epoch 140/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0932 - accuracy: 0.9957 - val_loss: 1.7375 - val_accuracy: 0.7159 - lr: 1.0000e-05
# Epoch 141/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0912 - accuracy: 0.9964 - val_loss: 1.8038 - val_accuracy: 0.6978 - lr: 1.0000e-05
# Epoch 142/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0891 - accuracy: 0.9976 - val_loss: 2.0324 - val_accuracy: 0.6888 - lr: 1.0000e-05
# Epoch 143/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0879 - accuracy: 0.9977 - val_loss: 1.5967 - val_accuracy: 0.7400 - lr: 1.0000e-05
# Epoch 144/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.0883 - accuracy: 0.9970 - val_loss: 1.6467 - val_accuracy: 0.7099 - lr: 1.0000e-05
# Epoch 145/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.0884 - accuracy: 0.9968 - val_loss: 1.8537 - val_accuracy: 0.7054 - lr: 1.0000e-05
# Epoch 146/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0883 - accuracy: 0.9976 - val_loss: 1.9002 - val_accuracy: 0.7046 - lr: 1.0000e-05
# Epoch 147/200
# 83/83 [==============================] - 39s 464ms/step - loss: 0.0889 - accuracy: 0.9966 - val_loss: 1.6717 - val_accuracy: 0.7340 - lr: 1.0000e-05
# Epoch 148/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0856 - accuracy: 0.9989 - val_loss: 1.6600 - val_accuracy: 0.7468 - lr: 1.0000e-05
# Epoch 149/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0888 - accuracy: 0.9966 - val_loss: 1.6980 - val_accuracy: 0.7234 - lr: 1.0000e-05
# Epoch 150/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0852 - accuracy: 0.9979 - val_loss: 1.6411 - val_accuracy: 0.7393 - lr: 1.0000e-05
# Epoch 151/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0868 - accuracy: 0.9966 - val_loss: 1.6494 - val_accuracy: 0.7302 - lr: 1.0000e-05
# Epoch 152/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0865 - accuracy: 0.9976 - val_loss: 1.7516 - val_accuracy: 0.7144 - lr: 1.0000e-05
# Epoch 153/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0853 - accuracy: 0.9981 - val_loss: 1.7626 - val_accuracy: 0.7091 - lr: 1.0000e-05
# Epoch 154/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0852 - accuracy: 0.9977 - val_loss: 1.6277 - val_accuracy: 0.7400 - lr: 1.0000e-05
# Epoch 155/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0827 - accuracy: 0.9985 - val_loss: 1.7625 - val_accuracy: 0.7046 - lr: 1.0000e-05
# Epoch 156/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0824 - accuracy: 0.9987 - val_loss: 1.7731 - val_accuracy: 0.7069 - lr: 1.0000e-05
# Epoch 157/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0847 - accuracy: 0.9974 - val_loss: 1.6601 - val_accuracy: 0.7174 - lr: 1.0000e-05
# Epoch 158/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0845 - accuracy: 0.9972 - val_loss: 1.6738 - val_accuracy: 0.7355 - lr: 1.0000e-05
# Epoch 159/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.0828 - accuracy: 0.9970 - val_loss: 1.6374 - val_accuracy: 0.7332 - lr: 1.0000e-05
# Epoch 160/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0838 - accuracy: 0.9964 - val_loss: 2.3186 - val_accuracy: 0.6571 - lr: 1.0000e-05
# Epoch 161/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0842 - accuracy: 0.9970 - val_loss: 1.7186 - val_accuracy: 0.7287 - lr: 1.0000e-05
# Epoch 162/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0855 - accuracy: 0.9972 - val_loss: 1.9325 - val_accuracy: 0.6986 - lr: 1.0000e-05
# Epoch 163/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0849 - accuracy: 0.9957 - val_loss: 2.0128 - val_accuracy: 0.6895 - lr: 1.0000e-05
# Epoch 164/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0814 - accuracy: 0.9979 - val_loss: 1.7466 - val_accuracy: 0.7491 - lr: 1.0000e-05
# Epoch 165/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0821 - accuracy: 0.9976 - val_loss: 1.7042 - val_accuracy: 0.7332 - lr: 1.0000e-05
# Epoch 166/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0797 - accuracy: 0.9985 - val_loss: 1.7325 - val_accuracy: 0.7249 - lr: 1.0000e-05
# Epoch 167/200
# 83/83 [==============================] - 39s 471ms/step - loss: 0.0804 - accuracy: 0.9979 - val_loss: 1.8759 - val_accuracy: 0.7016 - lr: 1.0000e-05
# Epoch 168/200
# 83/83 [==============================] - 39s 471ms/step - loss: 0.0812 - accuracy: 0.9979 - val_loss: 2.0010 - val_accuracy: 0.7008 - lr: 1.0000e-05
# Epoch 169/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0832 - accuracy: 0.9966 - val_loss: 1.7079 - val_accuracy: 0.7219 - lr: 1.0000e-05
# Epoch 170/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.0810 - accuracy: 0.9977 - val_loss: 1.9267 - val_accuracy: 0.7008 - lr: 1.0000e-05
# Epoch 171/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0838 - accuracy: 0.9964 - val_loss: 1.7215 - val_accuracy: 0.7227 - lr: 1.0000e-05
# Epoch 172/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.0804 - accuracy: 0.9970 - val_loss: 1.7345 - val_accuracy: 0.7355 - lr: 1.0000e-05
# Epoch 173/200
# 83/83 [==============================] - 39s 471ms/step - loss: 0.0834 - accuracy: 0.9960 - val_loss: 1.8394 - val_accuracy: 0.6963 - lr: 1.0000e-05
# Epoch 174/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0827 - accuracy: 0.9964 - val_loss: 1.7706 - val_accuracy: 0.7076 - lr: 1.0000e-05
# Epoch 175/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0790 - accuracy: 0.9970 - val_loss: 1.6998 - val_accuracy: 0.7197 - lr: 1.0000e-05
# Epoch 176/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0784 - accuracy: 0.9983 - val_loss: 2.0273 - val_accuracy: 0.6986 - lr: 1.0000e-05
# Epoch 177/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0835 - accuracy: 0.9968 - val_loss: 1.6475 - val_accuracy: 0.7325 - lr: 1.0000e-05
# Epoch 178/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0790 - accuracy: 0.9979 - val_loss: 1.7507 - val_accuracy: 0.7174 - lr: 1.0000e-05
# Epoch 179/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0803 - accuracy: 0.9972 - val_loss: 1.7051 - val_accuracy: 0.7197 - lr: 1.0000e-05
# Epoch 180/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0785 - accuracy: 0.9979 - val_loss: 1.8053 - val_accuracy: 0.7129 - lr: 1.0000e-05
# Epoch 181/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0801 - accuracy: 0.9966 - val_loss: 1.8906 - val_accuracy: 0.7001 - lr: 1.0000e-05
# Epoch 182/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0787 - accuracy: 0.9968 - val_loss: 1.8116 - val_accuracy: 0.7136 - lr: 1.0000e-05
# Epoch 183/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0799 - accuracy: 0.9972 - val_loss: 1.8789 - val_accuracy: 0.6971 - lr: 1.0000e-05
# Epoch 184/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0777 - accuracy: 0.9968 - val_loss: 1.8323 - val_accuracy: 0.7234 - lr: 1.0000e-05
# Epoch 185/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0771 - accuracy: 0.9979 - val_loss: 1.8291 - val_accuracy: 0.7212 - lr: 1.0000e-05
# Epoch 186/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0769 - accuracy: 0.9974 - val_loss: 1.8075 - val_accuracy: 0.7423 - lr: 1.0000e-05
# Epoch 187/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0819 - accuracy: 0.9957 - val_loss: 1.6721 - val_accuracy: 0.7604 - lr: 1.0000e-05
# Epoch 188/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.0782 - accuracy: 0.9970 - val_loss: 1.7212 - val_accuracy: 0.7317 - lr: 1.0000e-05
# Epoch 189/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0748 - accuracy: 0.9985 - val_loss: 1.7701 - val_accuracy: 0.7197 - lr: 1.0000e-05
# Epoch 190/200
# 83/83 [==============================] - 39s 465ms/step - loss: 0.0762 - accuracy: 0.9977 - val_loss: 2.3816 - val_accuracy: 0.6511 - lr: 1.0000e-05
# Epoch 191/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0762 - accuracy: 0.9977 - val_loss: 1.8888 - val_accuracy: 0.7061 - lr: 1.0000e-05
# Epoch 192/200
# 83/83 [==============================] - 40s 486ms/step - loss: 0.0745 - accuracy: 0.9987 - val_loss: 1.6787 - val_accuracy: 0.7498 - lr: 1.0000e-05
# Epoch 193/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.0753 - accuracy: 0.9976 - val_loss: 1.8285 - val_accuracy: 0.7227 - lr: 1.0000e-05
# Epoch 194/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.0782 - accuracy: 0.9968 - val_loss: 1.8821 - val_accuracy: 0.7121 - lr: 1.0000e-05
# Epoch 195/200
# 83/83 [==============================] - 39s 469ms/step - loss: 0.0739 - accuracy: 0.9972 - val_loss: 1.9689 - val_accuracy: 0.7182 - lr: 1.0000e-05
# Epoch 196/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0739 - accuracy: 0.9976 - val_loss: 1.9988 - val_accuracy: 0.6835 - lr: 1.0000e-05
# Epoch 197/200
# 83/83 [==============================] - 39s 470ms/step - loss: 0.0761 - accuracy: 0.9964 - val_loss: 1.8706 - val_accuracy: 0.7159 - lr: 1.0000e-05
# Epoch 198/200
# 83/83 [==============================] - 39s 468ms/step - loss: 0.0766 - accuracy: 0.9970 - val_loss: 1.8011 - val_accuracy: 0.7069 - lr: 1.0000e-05
# Epoch 199/200
# 83/83 [==============================] - 39s 467ms/step - loss: 0.0750 - accuracy: 0.9976 - val_loss: 1.7365 - val_accuracy: 0.7151 - lr: 1.0000e-05
# Epoch 200/200
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0773 - accuracy: 0.9962 - val_loss: 1.8461 - val_accuracy: 0.7061 - lr: 1.0000e-05

# %%
# Save the trained model
custom_CNN_model.save("models/custom_CNN_model_v2.h5")

# Save history
with open("models/custom_CNN_history_v2.pkl", "wb") as f:
    pkl.dump(custom_CNN_history.history, f)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot training and validation accuracy
axs[0].plot(custom_CNN_history.history["accuracy"], label="Training accuracy")
axs[0].plot(custom_CNN_history.history["val_accuracy"], label="Validation accuracy")
axs[0].set_title("Training and validation accuracy - Custom CNN (without segmentation)")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot training and validation loss
axs[1].plot(custom_CNN_history.history["loss"], label="Training loss")
axs[1].plot(custom_CNN_history.history["val_loss"], label="Validation loss")
axs[1].set_title("Training and validation loss - Custom CNN (without segmentation)")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. EfficientNet-B7

# %%
# Model configuration
epochs_number = 200

# Set optimizer
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# optimizer = SGD(learning_rate=0.001, momentum=0.9, nesterov=True)

# Set early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=5, verbose=1, mode='min', restore_best_weights=True)

# Set learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor="val_loss", patience=3, verbose=1, mode='min', factor=0.75, min_lr=0.00001)

# %%
""" Load the EfficientNet model """
base_efficientNet_model = EfficientNetB7(weights="imagenet", include_top=False, input_shape=(img_size, img_size, 3))

# Freeze convolutional layers
for layer in base_efficientNet_model.layers:
    layer.trainable = False

# Add custom classification head and create model
efficientNet_model = Sequential([
    base_efficientNet_model,
    GlobalAveragePooling2D(),
    Dense(1024, kernel_regularizer=L2(0.01), activation="relu"),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

# Compile model
efficientNet_model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

# Show model summary
efficientNet_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb7 (Functional)  (None, 7, 7, 2560)        64097687
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2560)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              2622464
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 66,726,297
# Trainable params: 2,626,562
# Non-trainable params: 64,099,735
# _________________________________________________________________

# %%
# Train the model
efficientNet_history = efficientNet_model.fit(
    train_generator,
    epochs=epochs_number,
    validation_data=val_generator,
    callbacks=[learning_rate_reduction, early_stopping],
)
# Out:
# Epoch 1/200
# 1081/1081 [==============================] - 274s 240ms/step - loss: 1.3402 - accuracy: 0.5029 - val_loss: 0.7473 - val_accuracy: 0.4984
# Epoch 2/200
# 1081/1081 [==============================] - 254s 235ms/step - loss: 0.7281 - accuracy: 0.4977 - val_loss: 0.8072 - val_accuracy: 0.5016
# Epoch 3/200
# 1081/1081 [==============================] - 257s 238ms/step - loss: 0.7218 - accuracy: 0.4995 - val_loss: 0.7181 - val_accuracy: 0.4984
# Epoch 4/200
# 1081/1081 [==============================] - 257s 238ms/step - loss: 0.7174 - accuracy: 0.4996 - val_loss: 0.7426 - val_accuracy: 0.4984
# Epoch 5/200
# 1081/1081 [==============================] - 257s 238ms/step - loss: 0.7131 - accuracy: 0.4986 - val_loss: 0.7070 - val_accuracy: 0.5016
# Epoch 6/200
# 1081/1081 [==============================] - 260s 240ms/step - loss: 0.7096 - accuracy: 0.5029 - val_loss: 0.7041 - val_accuracy: 0.4984
# Epoch 7/200
# 1081/1081 [==============================] - 259s 239ms/step - loss: 0.7083 - accuracy: 0.5006 - val_loss: 0.7859 - val_accuracy: 0.5016
# Epoch 8/200
# 1081/1081 [==============================] - 256s 237ms/step - loss: 0.7055 - accuracy: 0.5013 - val_loss: 0.7078 - val_accuracy: 0.4984
# Epoch 9/200
# 1081/1081 [==============================] - 259s 239ms/step - loss: 0.7050 - accuracy: 0.4985 - val_loss: 0.7009 - val_accuracy: 0.4984
# Epoch 10/200
# 1081/1081 [==============================] - 259s 239ms/step - loss: 0.7048 - accuracy: 0.5016 - val_loss: 0.7103 - val_accuracy: 0.4984
# Epoch 11/200
# 1081/1081 [==============================] - 256s 237ms/step - loss: 0.7043 - accuracy: 0.4977 - val_loss: 0.7196 - val_accuracy: 0.5016
# Epoch 12/200
# 1081/1081 [==============================] - 259s 239ms/step - loss: 0.7012 - accuracy: 0.4956 - val_loss: 0.7013 - val_accuracy: 0.5016
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# Epoch 13/200
# 1081/1081 [==============================] - 259s 239ms/step - loss: 0.6992 - accuracy: 0.4990 - val_loss: 0.6991 - val_accuracy: 0.5016
# Epoch 14/200
# 1081/1081 [==============================] - 258s 239ms/step - loss: 0.6990 - accuracy: 0.4988 - val_loss: 0.7268 - val_accuracy: 0.5016
# Epoch 15/200
# 1081/1081 [==============================] - 260s 240ms/step - loss: 0.6988 - accuracy: 0.4989 - val_loss: 0.7112 - val_accuracy: 0.4984
# Epoch 16/200
# 1081/1081 [==============================] - 260s 240ms/step - loss: 0.6985 - accuracy: 0.4981 - val_loss: 0.7022 - val_accuracy: 0.5016
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# Epoch 17/200
# 1081/1081 [==============================] - 258s 239ms/step - loss: 0.6970 - accuracy: 0.4990 - val_loss: 0.6962 - val_accuracy: 0.4984
# Epoch 18/200
# 1081/1081 [==============================] - 262s 242ms/step - loss: 0.6966 - accuracy: 0.5000 - val_loss: 0.6982 - val_accuracy: 0.4984
# Epoch 19/200
# 1081/1081 [==============================] - 260s 240ms/step - loss: 0.6971 - accuracy: 0.5010 - val_loss: 0.7156 - val_accuracy: 0.4984
# Epoch 20/200
# 1081/1081 [==============================] - 257s 238ms/step - loss: 0.6969 - accuracy: 0.4995 - val_loss: 0.6962 - val_accuracy: 0.5016
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# Epoch 21/200
# 1081/1081 [==============================] - 260s 240ms/step - loss: 0.6955 - accuracy: 0.5012 - val_loss: 0.6981 - val_accuracy: 0.5016
# Epoch 22/200
# 1081/1081 [==============================] - 257s 238ms/step - loss: 0.6955 - accuracy: 0.5007 - val_loss: 0.6944 - val_accuracy: 0.5016
# Epoch 23/200
# 1081/1081 [==============================] - 256s 237ms/step - loss: 0.6954 - accuracy: 0.4988 - val_loss: 0.6938 - val_accuracy: 0.4984
# Epoch 24/200
# 1081/1081 [==============================] - 262s 242ms/step - loss: 0.6954 - accuracy: 0.4981 - val_loss: 0.6940 - val_accuracy: 0.5016
# Epoch 25/200
# 1081/1081 [==============================] - 260s 241ms/step - loss: 0.6950 - accuracy: 0.5011 - val_loss: 0.6943 - val_accuracy: 0.5016
# Epoch 26/200
# 1081/1081 [==============================] - 259s 240ms/step - loss: 0.6948 - accuracy: 0.4979 - val_loss: 0.6941 - val_accuracy: 0.5016
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# Epoch 27/200
# 1081/1081 [==============================] - 264s 244ms/step - loss: 0.6945 - accuracy: 0.4990 - val_loss: 0.6942 - val_accuracy: 0.4984
# Epoch 28/200
# 1081/1081 [==============================] - 260s 240ms/step - loss: 0.6944 - accuracy: 0.5056 - val_loss: 0.6959 - val_accuracy: 0.5016
# Restoring model weights from the end of the best epoch.
# Epoch 00028: early stopping

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot training and validation accuracy
axs[0].plot(efficientNet_history.history["accuracy"], label="Training accuracy")
axs[0].plot(efficientNet_history.history["val_accuracy"], label="Validation accuracy")
axs[0].set_title("Training and validation accuracy - EfficientNetB7")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot training and validation loss
axs[1].plot(efficientNet_history.history["loss"], label="Training loss")
axs[1].plot(efficientNet_history.history["val_loss"], label="Validation loss")
axs[1].set_title("Training and validation loss - EfficientNetB7")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
# Save trained model
efficientNet_model.save("models/efficientNet_model.h5")

# Save history
with open("models/efficientNet_history.pkl", "wb") as f:
    pkl.dump(efficientNet_history.history, f)
# Out:
# c:\Users\farha\miniconda3\envs\py39_env\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %% [markdown]
# ## 3. VGG19 model

# %%
# Model configuration
epochs_number = 200

# Set optimizer
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# optimizer = SGD(learning_rate=0.001, momentum=0.9, nesterov=True)

# Set early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=5, verbose=1, mode='min', restore_best_weights=True)

# Set learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor="val_loss", patience=3, verbose=1, mode='min', factor=0.75, min_lr=0.00001)

# %%
""" Load the VGG19 model """
base_vgg_model = VGG19(weights="imagenet", include_top=False, input_shape=(img_size, img_size, 3))

# Freeze convolutional layers
for layer in base_vgg_model.layers:
    layer.trainable = False

# Add custom classification head and create model
vgg_model = Sequential([
    base_vgg_model,
    GlobalAveragePooling2D(),
    Dense(1024, kernel_regularizer=L2(0.01), activation="relu"),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

# Compile model
vgg_model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

# Show model summary
vgg_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 7, 7, 512)         20024384
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 20,555,842
# Trainable params: 529,410
# Non-trainable params: 20,026,432
# _________________________________________________________________

# %%
# Train the model
vgg_history = vgg_model.fit(
    train_generator,
    epochs=epochs_number,
    validation_data=val_generator,
    callbacks=[learning_rate_reduction, early_stopping],
)
# Out:
# Epoch 1/200
# 1081/1081 [==============================] - 241s 220ms/step - loss: 1.1870 - accuracy: 0.6015 - val_loss: 1.5693 - val_accuracy: 0.5016
# Epoch 2/200
# 1081/1081 [==============================] - 237s 219ms/step - loss: 0.7006 - accuracy: 0.6113 - val_loss: 1.2767 - val_accuracy: 0.5016
# Epoch 3/200
# 1081/1081 [==============================] - 235s 217ms/step - loss: 0.6886 - accuracy: 0.6185 - val_loss: 0.7289 - val_accuracy: 0.5448
# Epoch 4/200
# 1081/1081 [==============================] - 234s 217ms/step - loss: 0.6769 - accuracy: 0.6240 - val_loss: 0.7823 - val_accuracy: 0.4740
# Epoch 5/200
# 1081/1081 [==============================] - 234s 217ms/step - loss: 0.6733 - accuracy: 0.6270 - val_loss: 1.0056 - val_accuracy: 0.4990
# Epoch 6/200
# 1081/1081 [==============================] - 234s 216ms/step - loss: 0.6682 - accuracy: 0.6284 - val_loss: 0.7543 - val_accuracy: 0.5474
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# Epoch 7/200
# 1081/1081 [==============================] - 234s 217ms/step - loss: 0.6569 - accuracy: 0.6338 - val_loss: 0.8445 - val_accuracy: 0.5203
# Epoch 8/200
# 1081/1081 [==============================] - 234s 216ms/step - loss: 0.6558 - accuracy: 0.6384 - val_loss: 0.7573 - val_accuracy: 0.4943
# Restoring model weights from the end of the best epoch.
# Epoch 00008: early stopping

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot training and validation accuracy
axs[0].plot(vgg_history.history["accuracy"], label="Training accuracy")
axs[0].plot(vgg_history.history["val_accuracy"], label="Validation accuracy")
axs[0].set_title("Training and validation accuracy - VGG19")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot training and validation loss
axs[1].plot(vgg_history.history["loss"], label="Training loss")
axs[1].plot(vgg_history.history["val_loss"], label="Validation loss")
axs[1].set_title("Training and validation loss - VGG19")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
# Save the trained model
vgg_model.save("models/vgg_model.h5")

# Save the history
with open("models/vgg_history.pkl", "wb") as f:
    pkl.dump(vgg_history.history, f)

# %% [markdown]
# ## 4. ResNet-50 V2

# %% [markdown]
# #### Keras-Tuned model

# %%
# Model configuration
epochs_number = 200

# Checkpoint
checkpoint_filepath = "models/custom_resnet_model.h5"
model_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor="val_accuracy", mode="max", save_best_only=True)

# %%
class ResNetHyperModel(HyperModel):
    def __init__(self, img_size, num_classes):
        self.img_size = img_size
        self.num_classes = num_classes

    def build(self, hp):
        # Load ResNet50V2 model
        base_resNet_model = ResNet50V2(weights="imagenet", include_top=False, input_shape=(self.img_size, self.img_size, 3))

        # Freeze convolutional layers
        for layer in base_resNet_model.layers:
            layer.trainable = False

        # Add custom classification head and create model
        resnet_model = Sequential()
        resnet_model.add(base_resNet_model)
        resnet_model.add(GlobalAveragePooling2D())

        for i in range(hp.Int("num_dense_layers", 2, 5)):
            resnet_model.add(
                Dense(
                    units=hp.Int("dense_units_" + str(i), min_value=128, max_value=1024, step=256),
                    activation="relu",
                    kernel_regularizer=L2(hp.Float("l2_" + str(i), min_value=0.0001, max_value=0.01, sampling="LOG")),
                )
            )
            resnet_model.add(Dropout(rate=hp.Float("dropout_rate_" + str(i), min_value=0.0, max_value=0.5, step=0.05)))

        resnet_model.add(Dense(self.num_classes, activation="sigmoid"))

        # Set optimizer
        optimizer_choice = hp.Choice("optimizer", ["adam", "rmsprop", "sgd"])
        if optimizer_choice == "adam":
            optimizer = Adam(learning_rate=hp.Float("learning_rate", min_value=1e-4, max_value=1e-2, sampling="LOG", default=1e-3), beta_1=0.9, beta_2=0.999)
        elif optimizer_choice == "rmsprop":
            optimizer = RMSprop(
                learning_rate=hp.Float("learning_rate", min_value=1e-4, max_value=1e-2, sampling="LOG", default=1e-3), rho=0.9, epsilon=1e-08, decay=0.0
            )
        elif optimizer_choice == "sgd":
            optimizer = SGD(learning_rate=hp.Float("learning_rate", min_value=1e-4, max_value=1e-2, sampling="LOG", default=1e-3), momentum=0.9, nesterov=True)

        resnet_model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])

        return resnet_model


hypermodel = ResNetHyperModel(img_size, num_classes)

tuner = Hyperband(hypermodel, objective="val_accuracy", max_epochs=5, executions_per_trial=5, directory="hyperband_hpo", project_name="resnet")

# tuner.search_space_summary()

# %%
tuner.search(
    train_generator,
    validation_data=val_generator,
    epochs=(epochs_number / 2),
    verbose=1,
)

# %%
# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
best_hps

# %%
resnet_model = tuner.hypermodel.build(best_hps)
resnet_model.summary()

# %%
# Train the model
resnet_history = resnet_model.fit(
    train_generator,
    epochs=epochs_number,
    validation_data=val_generator,
    callbacks=[model_checkpoint]
)

# %%
# Save the trained model
resnet_model.save("models/final_resnet_model.h5")

# Save history
with open("models/final_resnet_history.pkl", "wb") as f:
    pkl.dump(resnet_history.history, f)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot training and validation accuracy
axs[0].plot(resnet_history.history["accuracy"], label="Training accuracy")
axs[0].plot(resnet_history.history["val_accuracy"], label="Validation accuracy")
axs[0].set_title("Training and validation accuracy - ResNet50V2")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot training and validation loss
axs[1].plot(resnet_history.history["loss"], label="Training loss")
axs[1].plot(resnet_history.history["val_loss"], label="Validation loss")
axs[1].set_title("Training and validation loss - ResNet50V2")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Base model

# %%
# Model configuration
epochs_number = 200

# Set optimizer
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# optimizer = SGD(learning_rate=0.001, momentum=0.9, nesterov=True)

# Set early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=5, verbose=1, mode='min', restore_best_weights=True)

# Set learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor="val_loss", patience=3, verbose=1, mode='min', factor=0.75, min_lr=0.00001)

# %%
# Load ResNet50V2 model
base_resNet_model = ResNet50V2(weights="imagenet", include_top=False, input_shape=(img_size, img_size, 3))

# Freeze convolutional layers
for layer in base_resNet_model.layers:
    layer.trainable = False

# Add custom classification head and create model
resnet_model = Sequential([
    base_resNet_model,
    GlobalAveragePooling2D(),
    Dense(1024, kernel_regularizer=L2(0.01), activation="relu"),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

# Compile model
resnet_model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

# Show model summary
resnet_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 7, 7, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 2048)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 2050
# =================================================================
# Total params: 25,669,122
# Trainable params: 2,102,274
# Non-trainable params: 23,566,848
# _________________________________________________________________

# %%
""" Train model """
resNet_history = resnet_model.fit(
    train_generator,
    epochs=epochs_number,
    validation_data=val_generator,
    callbacks=[learning_rate_reduction, early_stopping],
)
# Out:
# Epoch 1/200
# 1081/1081 [==============================] - 238s 217ms/step - loss: 1.6409 - accuracy: 0.5795 - val_loss: 0.8921 - val_accuracy: 0.4891
# Epoch 2/200
# 1081/1081 [==============================] - 234s 217ms/step - loss: 0.7877 - accuracy: 0.5845 - val_loss: 0.8051 - val_accuracy: 0.5474
# Epoch 3/200
# 1081/1081 [==============================] - 234s 216ms/step - loss: 0.7562 - accuracy: 0.5883 - val_loss: 0.8230 - val_accuracy: 0.5364
# Epoch 4/200
# 1081/1081 [==============================] - 233s 215ms/step - loss: 0.7389 - accuracy: 0.5911 - val_loss: 0.9430 - val_accuracy: 0.5021
# Epoch 5/200
# 1081/1081 [==============================] - 233s 216ms/step - loss: 0.7287 - accuracy: 0.5915 - val_loss: 0.7799 - val_accuracy: 0.5268
# Epoch 6/200
# 1081/1081 [==============================] - 233s 216ms/step - loss: 0.7177 - accuracy: 0.5945 - val_loss: 0.7891 - val_accuracy: 0.5003
# Epoch 7/200
# 1081/1081 [==============================] - 233s 216ms/step - loss: 0.7134 - accuracy: 0.5961 - val_loss: 0.7629 - val_accuracy: 0.4987
# Epoch 8/200
# 1081/1081 [==============================] - 232s 215ms/step - loss: 0.7037 - accuracy: 0.6055 - val_loss: 0.7405 - val_accuracy: 0.5552
# Epoch 9/200
# 1081/1081 [==============================] - 232s 215ms/step - loss: 0.7012 - accuracy: 0.6024 - val_loss: 0.7322 - val_accuracy: 0.5349
# Epoch 10/200
# 1081/1081 [==============================] - 232s 215ms/step - loss: 0.7061 - accuracy: 0.5931 - val_loss: 0.7509 - val_accuracy: 0.5370
# Epoch 11/200
# 1081/1081 [==============================] - 234s 216ms/step - loss: 0.7227 - accuracy: 0.5769 - val_loss: 0.8949 - val_accuracy: 0.5065
# Epoch 12/200
# 1081/1081 [==============================] - 234s 216ms/step - loss: 0.7124 - accuracy: 0.5830 - val_loss: 0.8059 - val_accuracy: 0.4898
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# Epoch 13/200
# 1081/1081 [==============================] - 232s 215ms/step - loss: 0.6954 - accuracy: 0.5998 - val_loss: 0.7578 - val_accuracy: 0.5070
# Epoch 14/200
# 1081/1081 [==============================] - 234s 216ms/step - loss: 0.6909 - accuracy: 0.6021 - val_loss: 0.7641 - val_accuracy: 0.4599
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

""" Plot training and validation accuracy """
axs[0].plot(resNet_history.history["accuracy"], label="Training accuracy")
axs[0].plot(resNet_history.history["val_accuracy"], label="Validation accuracy")
axs[0].set_title("Training and validation accuracy - ResNet50V2")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

""" Plot training and validation loss """
axs[1].plot(resNet_history.history["loss"], label="Training loss")
axs[1].plot(resNet_history.history["val_loss"], label="Validation loss")
axs[1].set_title("Training and validation loss - ResNet50V2")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
""" Save model """
resnet_model.save("models/resNet_model.h5")

""" Save history """
with open("models/resNet_history.pkl", "wb") as f:
    pkl.dump(resNet_history.history, f)

# %% [markdown]
# ## 5. DenseNet-121 model

# %%
# Model configuration
epochs_number = 200

# Set optimizer
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# optimizer = SGD(learning_rate=0.001, momentum=0.9, nesterov=True)

# Set early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=5, verbose=1, mode='min', restore_best_weights=True)

# Set learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor="val_loss", patience=3, verbose=1, mode='min', factor=0.75, min_lr=0.00001)

# %%
# Load pre-trained DenseNet121 model
base_denseNet_model = DenseNet121(weights="imagenet", include_top=False, input_shape=(img_size, img_size, 3))

# Freeze convolutional layers
for layer in base_denseNet_model.layers:
    layer.trainable = False

# Add custom classification head and create model
denseNet_model = Sequential([
    base_denseNet_model,
    GlobalAveragePooling2D(),
    Dense(1024, kernel_regularizer=L2(0.01), activation="relu"),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

# Compile model
denseNet_model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

# Show model summary
denseNet_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 1024)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 2050
# =================================================================
# Total params: 8,093,250
# Trainable params: 1,053,698
# Non-trainable params: 7,039,552
# _________________________________________________________________

# %%
""" Train model """
denseNet_history = denseNet_model.fit(
    train_generator,
    epochs=epochs_number,
    validation_data=val_generator,
    callbacks=[learning_rate_reduction, early_stopping],
)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot training and validation accuracy
axs[0].plot(denseNet_history.history["accuracy"], label="Training accuracy")
axs[0].plot(denseNet_history.history["val_accuracy"], label="Validation accuracy")
axs[0].set_title("Training and validation accuracy - DenseNet121")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot training and validation loss
axs[1].plot(denseNet_history.history["loss"], label="Training loss")
axs[1].plot(denseNet_history.history["val_loss"], label="Validation loss")
axs[1].set_title("Training and validation loss - DenseNet121")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
# Save trained model
denseNet_model.save("models/denseNet_model.h5")

# Save history
with open("models/denseNet_history.pkl", "wb") as f:
    pkl.dump(denseNet_history.history, f)

# %% [markdown]
# ## 6. Inception-V3 model

# %%
# Model configuration
epochs_number = 200

# Set optimizer
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# optimizer = SGD(learning_rate=0.001, momentum=0.9, nesterov=True)

# Set early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=5, verbose=1, mode='min', restore_best_weights=True)

# Set learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor="val_loss", patience=3, verbose=1, mode='min', factor=0.75, min_lr=0.00001)

# %%
""" Load the Inception model """
base_inception_model = InceptionV3(weights="imagenet", include_top=False, input_shape=(img_size, img_size, 3))

# Freeze convolutional layers
for layer in base_inception_model.layers:
    layer.trainable = False

# Add custom classification head and create model
inception_model = Sequential([
    base_inception_model,
    GlobalAveragePooling2D(),
    Dense(1024, kernel_regularizer=L2(0.01), activation="relu"),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

# Compile model
inception_model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

# Show model summary
inception_model.summary()

# %%
# Train the model
inception_history = inception_model.fit(
    train_generator,
    epochs=epochs_number,
    validation_data=val_generator,
    callbacks=[learning_rate_reduction, early_stopping],
)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot training and validation accuracy
axs[0].plot(inception_history.history["accuracy"], label="Training accuracy")
axs[0].plot(inception_history.history["val_accuracy"], label="Validation accuracy")
axs[0].set_title("Training and validation accuracy - InceptionV3")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot training and validation loss
axs[1].plot(inception_history.history["loss"], label="Training loss")
axs[1].plot(inception_history.history["val_loss"], label="Validation loss")
axs[1].set_title("Training and validation loss - IncetionV3")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
# Save trained model
inception_model.save("models/inception_model.h5")

# Save history
with open("models/inception_history.pkl", "wb") as f:
    pkl.dump(inception_history.history, f)

# %% [markdown]
# ## 7. MobileNet model

# %%
# Model configuration
epochs_number = 200

# Set optimizer
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
# optimizer = RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# optimizer = SGD(learning_rate=0.001, momentum=0.9, nesterov=True)

# Set early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=5, verbose=1, mode='min', restore_best_weights=True)

# Set learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor="val_loss", patience=3, verbose=1, mode='min', factor=0.75, min_lr=0.00001)

# %%
""" Load the MobileNet model """
base_mobileNet_model = MobileNetV3Large(weights="imagenet", include_top=False, input_shape=(img_size, img_size, 3))

# Freeze convolutional layers
for layer in base_mobileNet_model.layers:
    layer.trainable = False

# Add custom classification head and create model
mobileNet_model = Sequential([
    base_mobileNet_model,
    GlobalAveragePooling2D(),
    Dense(1024, kernel_regularizer=L2(0.01), activation="relu"),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

# Compile model
mobileNet_model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

# Show model summary
mobileNet_model.summary()

# %%
# Train the model
mobileNet_history = mobileNet_model.fit(
    train_generator,
    epochs=epochs_number,
    validation_data=val_generator,
    callbacks=[learning_rate_reduction, early_stopping],
)

# %%
# Save trained model
mobileNet_model.save("models/mobileNet_model.h5")

# Save history
with open("models/mobileNet_history.pkl", "wb") as f:
    pkl.dump(mobileNet_history.history, f)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot training and validation accuracy
axs[0].plot(mobileNet_history.history["accuracy"], label="Training accuracy")
axs[0].plot(mobileNet_history.history["val_accuracy"], label="Validation accuracy")
axs[0].set_title("Training and validation accuracy - MobileNetV3")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot training and validation loss
axs[1].plot(mobileNet_history.history["loss"], label="Training loss")
axs[1].plot(mobileNet_history.history["val_loss"], label="Validation loss")
axs[1].set_title("Training and validation loss - MobileNetV3")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate models

# %%
# Table comparing the performance of models
resNet_accuracy = resNet_history.history["accuracy"][-1]
resNet_val_accuracy = resNet_history.history["val_accuracy"][-1]

denseNet_accuracy = denseNet_history.history["accuracy"][-1]
denseNet_val_accuracy = denseNet_history.history["val_accuracy"][-1]

vgg_accuracy = vgg_history.history["accuracy"][-1]
vgg_val_accuracy = vgg_history.history["val_accuracy"][-1]

inception_accuracy = inception_history.history["accuracy"][-1]
inception_val_accuracy = inception_history.history["val_accuracy"][-1]

mobileNet_accuracy = mobileNet_history.history["accuracy"][-1]
mobileNet_val_accuracy = mobileNet_history.history["val_accuracy"][-1]

efficientNet_accuracy = efficientNet_history.history["accuracy"][-1]
efficientNet_val_accuracy = efficientNet_history.history["val_accuracy"][-1]

custom_CNN_accuracy = custom_CNN_history.history["accuracy"][-1]
custom_CNN_val_accuracy = custom_CNN_history.history["val_accuracy"][-1]

model_comparison = pd.DataFrame(
    {
        "Model": [
            "ResNet50V2",
            "DenseNet121",
            "VGG19",
            "InceptionV3",
            "MobileNetV3",
            "EfficientNetB7",
            "Custom CNN"
        ],
        "Train Accuracy": [
            resNet_accuracy,
            denseNet_accuracy,
            vgg_accuracy,
            inception_accuracy,
            mobileNet_accuracy,
            efficientNet_accuracy,
            custom_CNN_accuracy,
        ],
        "Validation Accuracy": [
            resNet_val_accuracy,
            denseNet_val_accuracy,
            vgg_val_accuracy,
            inception_val_accuracy,
            mobileNet_val_accuracy,
            efficientNet_val_accuracy,
            custom_CNN_val_accuracy,
        ],
    }
)

# Sort the models by validation accuracy
model_comparison = model_comparison.sort_values(by="Validation Accuracy", ascending=False).reset_index(drop=True)

model_comparison

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="Model", y="Validation Accuracy", data=model_comparison, palette="viridis")
plt.title("Comparison of Validation Accuracies")
plt.show()

# %%
# import visualkeras

# model = custom_CNN_model

# # visualkeras.layered_view(model).show()
# # visualkeras.layered_view(model, to_file='output.png')
# # visualkeras.layered_view(model, to_file='output.png').show()

# visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=1289x1195>
